# %% [markdown]
# # 실전 데이터 분석 2
# - 범죄 현황 분석
# - 서울시 5대 범죄 발생 현황 통계

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'New Gulim'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

# %%
CRIME = pd.read_excel('CRIME.xlsx')
# Out:
# C:\Users\COM\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CRIME.head()
# Out:
#    자치구별(1)  자치구별(2)   2024 2024.1 2024.2 2024.3 2024.4 2024.5   2024.6  \
# 0  자치구별(1)  자치구별(2)     합계     합계     합계     합계     합계     합계       합계
# 1  자치구별(1)  자치구별(2)     소계     소계     살인     살인     강도     강도  강간·강제추행
# 2  자치구별(1)  자치구별(2)     발생     검거     발생     검거     발생     검거       발생
# 3       합계       소계  80819  63275    149    137     87     85     5523
# 4      NaN      종로구   2765   3248      2      3      5     10      209
#
#     2024.7 2024.8 2024.9 2024.10 2024.11
# 0       합계     합계     합계      합계      합계
# 1  강간·강제추행     절도     절도      폭력      폭력
# 2       검거     발생     검거      발생      검거
# 3     5183  35506  22796   39554   35074
# 4      933   1183   1056    1366    1246

# %%
CRIME = pd.read_excel('CRIME.xlsx', skiprows=3)
# Out:
# C:\Users\COM\miniconda3\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
CRIME.head(3)
# Out:
#   자치구별(1) 자치구별(2)     발생     검거  발생.1  검거.1 발생.2 검거.2  발생.3  검거.3   발생.4  \
# 0      합계      소계  80819  63275   149   137   87   85  5523  5183  35506
# 1     NaN     종로구   2765   3248     2     3    5   10   209   933   1183
# 2     NaN      중구   2955   2180     5     4    5    5   177   121   1398
#
#     검거.4   발생.5   검거.5
# 0  22796  39554  35074
# 1   1056   1366   1246
# 2    816   1370   1234

# %%
del CRIME['자치구별(1)']
del CRIME['발생']
del CRIME['검거']

# %%
CRIME.head(3)
# Out:
#   자치구별(2)  발생.1  검거.1 발생.2 검거.2  발생.3  검거.3   발생.4   검거.4   발생.5   검거.5
# 0      소계   149   137   87   85  5523  5183  35506  22796  39554  35074
# 1     종로구     2     3    5   10   209   933   1183   1056   1366   1246
# 2      중구     5     4    5    5   177   121   1398    816   1370   1234

# %%
CRIME.columns = ['구별', '살인발생', '살인검거', '강도발생', '강도검거', '강간강제추행발생', '강간강제추행검거', '절도발생', '절도검거'
                , '폭력발생', '폭력검거']

# %%
CRIME.head(3)
# Out:
#     구별  살인발생  살인검거 강도발생 강도검거  강간강제추행발생  강간강제추행검거   절도발생   절도검거   폭력발생   폭력검거
# 0   소계   149   137   87   85      5523      5183  35506  22796  39554  35074
# 1  종로구     2     3    5   10       209       933   1183   1056   1366   1246
# 2   중구     5     4    5    5       177       121   1398    816   1370   1234

# %%
CRIME.drop(0, inplace=True)

# %%
CRIME.head(2)
# Out:
#     구별  살인발생  살인검거 강도발생 강도검거  강간강제추행발생  강간강제추행검거  절도발생  절도검거  폭력발생  폭력검거
# 1  종로구     2     3    5   10       209       933  1183  1056  1366  1246
# 2   중구     5     4    5    5       177       121  1398   816  1370  1234

# %% [markdown]
# # 검거율 추가

# %%
CRIME.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구별        25 non-null     object
#  1   살인발생      25 non-null     int64
#  2   살인검거      25 non-null     int64
#  3   강도발생      25 non-null     object
#  4   강도검거      25 non-null     object
#  5   강간강제추행발생  25 non-null     int64
#  6   강간강제추행검거  25 non-null     int64
#  7   절도발생      25 non-null     int64
#  8   절도검거      25 non-null     int64
#  9   폭력발생      25 non-null     int64
#  10  폭력검거      25 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 2.3+ KB

# %%
CRIME.loc[9, '강도발생']
# Out:
# '-'

# %%
type(CRIME.loc[9, '강도발생'])
# Out:
# str

# %%
CRIME.replace('-', 0)
# Out:
# C:\Users\COM\AppData\Local\Temp\ipykernel_28580\1601430732.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   CRIME.replace('-', 0)
#       구별  살인발생  살인검거  강도발생  강도검거  강간강제추행발생  강간강제추행검거  절도발생  절도검거  폭력발생  폭력검거
# 1    종로구     2     3     5    10       209       933  1183  1056  1366  1246
# 2     중구     5     4     5     5       177       121  1398   816  1370  1234
# 3    용산구    10     6     4     3       267       235  1082   589  1959  1642
# 4    성동구     5     6     3     3       114        90   966   544  1029   867
# 5    광진구     2     2     6     7       235       183  1320   942  1307  1085
# 6   동대문구     7     6     4     2       125       110  1617  1060  1463  1304
# 7    중랑구     5     5     2     2       143       116  1437   931  1582  1409
# 8    성북구     3     2     1     1       146       109   884   578  1150  1059
# 9    강북구     6     6     0     0       142       112   970   835  1171  1108
# 10   도봉구     7     3     0     1        73        61   800   520   861   794
# 11   노원구     7     5     3     2       146       126  1508   899  1437  1377
# 12   은평구     9     9     1     4       132       108  1517   993  1558  1349
# 13  서대문구     3     3     0     0       131       119  1014   588   906   776
# 14   마포구     4     3     4     5       503       389  1471   949  1909  1687
# 15   양천구     4     4     1     1       109        88  1518   832  1368  1188
# 16   강서구     5     5     6     4       271       214  1670  1275  2056  1913
# 17   구로구     7     6     0     1       186       133  1572   918  1613  1405
# 18   금천구     7     6     3     3       129        99   886   685   992   917
# 19  영등포구    11    11     6     5       284       204  1791  1323  2075  1804
# 20   동작구     1     1     1     1       180       109  1085   598  1187  1051
# 21   관악구     4     5     3     2       338       284  1971  1212  2169  2013
# 22   서초구    10    10     5     2       364       312  1585  1017  1824  1587
# 23   강남구    16    17    17    12       640       533  2097  1140  3337  2868
# 24   송파구     6     5     3     5       315       255  2502  1506  2348  2019
# 25   강동구     3     4     4     4       164       140  1662   990  1517  1372

# %%
CRIME = CRIME.replace('-', 0)
# Out:
# C:\Users\COM\AppData\Local\Temp\ipykernel_28580\3485709669.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   CRIME = CRIME.replace('-', 0)

# %%
CRIME.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구별        25 non-null     object
#  1   살인발생      25 non-null     int64
#  2   살인검거      25 non-null     int64
#  3   강도발생      25 non-null     int64
#  4   강도검거      25 non-null     int64
#  5   강간강제추행발생  25 non-null     int64
#  6   강간강제추행검거  25 non-null     int64
#  7   절도발생      25 non-null     int64
#  8   절도검거      25 non-null     int64
#  9   폭력발생      25 non-null     int64
#  10  폭력검거      25 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# ### 검거율 = (검거/발생) * 100

# %%
crime_index = ['살인', '강도', '강간강제추행', '절도', '폭력']

# %%
for crime in crime_index : 
    CRIME[crime+'검거율'] = CRIME[crime+'검거']/CRIME[crime+'발생'] *100

# %%
CRIME
# Out:
#       구별  살인발생  살인검거  강도발생  강도검거  강간강제추행발생  강간강제추행검거  절도발생  절도검거  폭력발생  폭력검거  \
# 1    종로구     2     3     5    10       209       933  1183  1056  1366  1246
# 2     중구     5     4     5     5       177       121  1398   816  1370  1234
# 3    용산구    10     6     4     3       267       235  1082   589  1959  1642
# 4    성동구     5     6     3     3       114        90   966   544  1029   867
# 5    광진구     2     2     6     7       235       183  1320   942  1307  1085
# 6   동대문구     7     6     4     2       125       110  1617  1060  1463  1304
# 7    중랑구     5     5     2     2       143       116  1437   931  1582  1409
# 8    성북구     3     2     1     1       146       109   884   578  1150  1059
# 9    강북구     6     6     0     0       142       112   970   835  1171  1108
# 10   도봉구     7     3     0     1        73        61   800   520   861   794
# 11   노원구     7     5     3     2       146       126  1508   899  1437  1377
# 12   은평구     9     9     1     4       132       108  1517   993  1558  1349
# 13  서대문구     3     3     0     0       131       119  1014   588   906   776
# 14   마포구     4     3     4     5       503       389  1471   949  1909  1687
# 15   양천구     4     4     1     1       109        88  1518   832  1368  1188
# 16   강서구     5     5     6     4       271       214  1670  1275  2056  1913
# 17   구로구     7     6     0     1       186       133  1572   918  1613  1405
# 18   금천구     7     6     3     3       129        99   886   685   992   917
# 19  영등포구    11    11     6     5       284       204  1791  1323  2075  1804
# 20   동작구     1     1     1     1       180       109  1085   598  1187  1051
# 21   관악구     4     5     3     2       338       284  1971  1212  2169  2013
# 22   서초구    10    10     5     2       364       312  1585  1017  1824  1587
# 23   강남구    16    17    17    12       640       533  2097  1140  3337  2868
# 24   송파구     6     5     3     5       315       255  2502  1506  2348  2019
# 25   강동구     3     4     4     4       164       140  1662   990  1517  1372
#
#          살인검거율       강도검거율   강간강제추행검거율      절도검거율      폭력검거율
# 1   150.000000  200.000000  446.411483  89.264582  91.215227
# 2    80.000000  100.000000   68.361582  58.369099  90.072993
# 3    60.000000   75.000000   88.014981  54.436229  83.818275
# 4   120.000000  100.000000   78.947368  56.314700  84.256560
# 5   100.000000  116.666667   77.872340  71.363636  83.014537
# 6    85.714286   50.000000   88.000000  65.553494  89.131921
# 7   100.000000  100.000000   81.118881  64.787752  89.064475
# 8    66.666667  100.000000   74.657534  65.384615  92.086957
# 9   100.000000         NaN   78.873239  86.082474  94.619983
# 10   42.857143         inf   83.561644  65.000000  92.218351
# 11   71.428571   66.666667   86.301370  59.615385  95.824635
# 12  100.000000  400.000000   81.818182  65.458141  86.585366
# 13  100.000000         NaN   90.839695  57.988166  85.651214
# 14   75.000000  125.000000   77.335984  64.513936  88.370875
# 15  100.000000  100.000000   80.733945  54.808959  86.842105
# 16  100.000000   66.666667   78.966790  76.347305  93.044747
# 17   85.714286         inf   71.505376  58.396947  87.104774
# 18   85.714286  100.000000   76.744186  77.313770  92.439516
# 19  100.000000   83.333333   71.830986  73.869347  86.939759
# 20  100.000000  100.000000   60.555556  55.115207  88.542544
# 21  125.000000   66.666667   84.023669  61.491629  92.807746
# 22  100.000000   40.000000   85.714286  64.164038  87.006579
# 23  106.250000   70.588235   83.281250  54.363376  85.945460
# 24   83.333333  166.666667   80.952381  60.191847  85.988075
# 25  133.333333  100.000000   85.365854  59.566787  90.441661

# %%
CRIME['살인검거율'] >100
# Out:
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# Name: 살인검거율, dtype: bool

# %%
CRIME.loc[CRIME['살인검거율'] >100, '살인검거율' ]
# Out:
# 1     150.000000
# 4     120.000000
# 21    125.000000
# 23    106.250000
# 25    133.333333
# Name: 살인검거율, dtype: float64

# %%
CRIME.loc[CRIME['살인검거율'] >100, '살인검거율' ] = 100

# %%
CRIME.head(3)
# Out:
#     구별  살인발생  살인검거  강도발생  강도검거  강간강제추행발생  강간강제추행검거  절도발생  절도검거  폭력발생  폭력검거  \
# 1  종로구     2     3     5    10       209       933  1183  1056  1366  1246
# 2   중구     5     4     5     5       177       121  1398   816  1370  1234
# 3  용산구    10     6     4     3       267       235  1082   589  1959  1642
#
#    살인검거율  강도검거율   강간강제추행검거율      절도검거율      폭력검거율
# 1  100.0  200.0  446.411483  89.264582  91.215227
# 2   80.0  100.0   68.361582  58.369099  90.072993
# 3   60.0   75.0   88.014981  54.436229  83.818275

# %%
for crime in crime_index: 
    CRIME.loc[CRIME[crime+'검거율'] > 100, crime+'검거율'] = 100

# %%
CRIME.head(3)
# Out:
#     구별  살인발생  살인검거  강도발생  강도검거  강간강제추행발생  강간강제추행검거  절도발생  절도검거  폭력발생  폭력검거  \
# 1  종로구     2     3     5    10       209       933  1183  1056  1366  1246
# 2   중구     5     4     5     5       177       121  1398   816  1370  1234
# 3  용산구    10     6     4     3       267       235  1082   589  1959  1642
#
#    살인검거율  강도검거율   강간강제추행검거율      절도검거율      폭력검거율
# 1  100.0  100.0  100.000000  89.264582  91.215227
# 2   80.0  100.0   68.361582  58.369099  90.072993
# 3   60.0   75.0   88.014981  54.436229  83.818275

# %%
CRIME.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   살인발생       25 non-null     int64
#  2   살인검거       25 non-null     int64
#  3   강도발생       25 non-null     int64
#  4   강도검거       25 non-null     int64
#  5   강간강제추행발생   25 non-null     int64
#  6   강간강제추행검거   25 non-null     int64
#  7   절도발생       25 non-null     int64
#  8   절도검거       25 non-null     int64
#  9   폭력발생       25 non-null     int64
#  10  폭력검거       25 non-null     int64
#  11  살인검거율      25 non-null     float64
#  12  강도검거율      23 non-null     float64
#  13  강간강제추행검거율  25 non-null     float64
#  14  절도검거율      25 non-null     float64
#  15  폭력검거율      25 non-null     float64
info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   구별         25 non-null     object
#  1   살인발생       25 non-null     int64
#  2   살인검거       25 non-null     int64
#  3   강도발생       25 non-null     int64
#  4   강도검거       25 non-null     int64
#  5   강간강제추행발생   25 non-null     int64
#  6   강간강제추행검거   25 non-null     int64
#  7   절도발생       25 non-null     int64
#  8   절도검거       25 non-null     int64
#  9   폭력발생       25 non-null     int64
#  10  폭력검거       25 non-null     int64
#  11  살인검거율      25 non-null     float64
#  12  강도검거율      25 non-null     float64
#  13  강간강제추행검거율  25 non-null     float64
#  14  절도검거율      25 non-null     float64
#  15  폭력검거율      25 non-null     float64
# dtypes: float64(5), int64(10), object(1)
# memory usage: 3.3+ KB

# %%
for crime in crime_index:
    del CRIME[crime+'검거']

# %%
CRIME.head(3)
# Out:
#     구별  살인발생  강도발생  강간강제추행발생  절도발생  폭력발생  살인검거율  강도검거율   강간강제추행검거율      절도검거율  \
# 1  종로구     2     5       209  1183  1366  100.0  100.0  100.000000  89.264582
# 2   중구     5     5       177  1398  1370   80.0  100.0   68.361582  58.369099
# 3  용산구    10     4       267  1082  1959   60.0   75.0   88.014981  54.436229
#
#        폭력검거율
# 1  91.215227
# 2  90.072993
# 3  83.818275

# %%
for crime in CRIME.columns:
    if crime.endswith('발생'):
        print(crime[:-2])
# Out:
# 살인
# 강도
# 강간강제추행
# 절도
# 폭력

# %%
for crime in CRIME.columns:
    if crime.endswith('발생'):
        CRIME.rename(columns = {crime : crime[:-2]}, inplace = True)

# %%
CRIME.head(3)
# Out:
#     구별  살인  강도  강간강제추행    절도    폭력  살인검거율  강도검거율   강간강제추행검거율      절도검거율  \
# 1  종로구   2   5     209  1183  1366  100.0  100.0  100.000000  89.264582
# 2   중구   5   5     177  1398  1370   80.0  100.0   68.361582  58.369099
# 3  용산구  10   4     267  1082  1959   60.0   75.0   88.014981  54.436229
#
#        폭력검거율
# 1  91.215227
# 2  90.072993
# 3  83.818275

# %% [markdown]
# # 데이터 정규화 (Normalize)
# - MinMaxScaler

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\com\miniconda3\lib\site-packages (from scikit-learn) (2.0.2)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0

# %%
from sklearn import preprocessing

# %%
x = CRIME[crime_index]

# %%
x
# Out:
#     살인  강도  강간강제추행    절도    폭력
# 1    2   5     209  1183  1366
# 2    5   5     177  1398  1370
# 3   10   4     267  1082  1959
# 4    5   3     114   966  1029
# 5    2   6     235  1320  1307
# 6    7   4     125  1617  1463
# 7    5   2     143  1437  1582
# 8    3   1     146   884  1150
# 9    6   0     142   970  1171
# 10   7   0      73   800   861
# 11   7   3     146  1508  1437
# 12   9   1     132  1517  1558
# 13   3   0     131  1014   906
# 14   4   4     503  1471  1909
# 15   4   1     109  1518  1368
# 16   5   6     271  1670  2056
# 17   7   0     186  1572  1613
# 18   7   3     129   886   992
# 19  11   6     284  1791  2075
# 20   1   1     180  1085  1187
# 21   4   3     338  1971  2169
# 22  10   5     364  1585  1824
# 23  16  17     640  2097  3337
# 24   6   3     315  2502  2348
# 25   3   4     164  1662  1517

# %%
min_max_scaler = preprocessing.MinMaxScaler() 
x_scaled = min_max_scaler.fit_transform(x.astype(float))

# %%
x_scaled
# Out:
# array([[0.06666667, 0.29411765, 0.23985891, 0.22502938, 0.203958  ],
#        [0.26666667, 0.29411765, 0.18342152, 0.35135135, 0.20557351],
#        [0.6       , 0.23529412, 0.34215168, 0.16568743, 0.44345719],
#        [0.26666667, 0.17647059, 0.07231041, 0.09753231, 0.06785137],
#        [0.06666667, 0.35294118, 0.28571429, 0.30552291, 0.18012924],
#        [0.4       , 0.23529412, 0.09171076, 0.4800235 , 0.24313409],
#        [0.26666667, 0.11764706, 0.12345679, 0.37426557, 0.29119548],
#        [0.13333333, 0.05882353, 0.1287478 , 0.0493537 , 0.11672052],
#        [0.33333333, 0.        , 0.12169312, 0.09988249, 0.12520194],
#        [0.4       , 0.        , 0.        , 0.        , 0.        ],
#        [0.4       , 0.17647059, 0.1287478 , 0.4159812 , 0.23263328],
#        [0.53333333, 0.05882353, 0.10405644, 0.4212691 , 0.28150242],
#        [0.13333333, 0.        , 0.10229277, 0.12573443, 0.01817447],
#        [0.2       , 0.23529412, 0.75837743, 0.39424207, 0.42326333],
#        [0.2       , 0.05882353, 0.06349206, 0.42185664, 0.20476575],
#        [0.26666667, 0.35294118, 0.34920635, 0.51116334, 0.48263328],
#        [0.4       , 0.        , 0.19929453, 0.45358402, 0.30371567],
#        [0.4       , 0.17647059, 0.09876543, 0.05052879, 0.05290792],
#        [0.66666667, 0.35294118, 0.37213404, 0.58225617, 0.49030695],
#        [0.        , 0.05882353, 0.18871252, 0.16745006, 0.13166397],
#        [0.2       , 0.17647059, 0.46737213, 0.6880141 , 0.52827141],
#        [0.6       , 0.29411765, 0.51322751, 0.46122209, 0.38893376],
#        [1.        , 1.        , 1.        , 0.76204465, 1.        ],
#        [0.33333333, 0.17647059, 0.42680776, 1.        , 0.60056543],
#        [0.13333333, 0.23529412, 0.16049383, 0.50646298, 0.26494346]])

# %%
CRIME_norm = pd.DataFrame(x_scaled)

# %%
CRIME_norm
# Out:
#            0         1         2         3         4
# 0   0.066667  0.294118  0.239859  0.225029  0.203958
# 1   0.266667  0.294118  0.183422  0.351351  0.205574
# 2   0.600000  0.235294  0.342152  0.165687  0.443457
# 3   0.266667  0.176471  0.072310  0.097532  0.067851
# 4   0.066667  0.352941  0.285714  0.305523  0.180129
# 5   0.400000  0.235294  0.091711  0.480024  0.243134
# 6   0.266667  0.117647  0.123457  0.374266  0.291195
# 7   0.133333  0.058824  0.128748  0.049354  0.116721
# 8   0.333333  0.000000  0.121693  0.099882  0.125202
# 9   0.400000  0.000000  0.000000  0.000000  0.000000
# 10  0.400000  0.176471  0.128748  0.415981  0.232633
# 11  0.533333  0.058824  0.104056  0.421269  0.281502
# 12  0.133333  0.000000  0.102293  0.125734  0.018174
# 13  0.200000  0.235294  0.758377  0.394242  0.423263
# 14  0.200000  0.058824  0.063492  0.421857  0.204766
# 15  0.266667  0.352941  0.349206  0.511163  0.482633
# 16  0.400000  0.000000  0.199295  0.453584  0.303716
# 17  0.400000  0.176471  0.098765  0.050529  0.052908
# 18  0.666667  0.352941  0.372134  0.582256  0.490307
# 19  0.000000  0.058824  0.188713  0.167450  0.131664
# 20  0.200000  0.176471  0.467372  0.688014  0.528271
# 21  0.600000  0.294118  0.513228  0.461222  0.388934
# 22  1.000000  1.000000  1.000000  0.762045  1.000000
# 23  0.333333  0.176471  0.426808  1.000000  0.600565
# 24  0.133333  0.235294  0.160494  0.506463  0.264943

# %%
CRIME_norm = pd.DataFrame(x_scaled, columns=x.columns, index = CRIME['구별'])

# %%
CRIME_norm.head(3)
# Out:
#            살인        강도    강간강제추행        절도        폭력
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958
# 중구   0.266667  0.294118  0.183422  0.351351  0.205574
# 용산구  0.600000  0.235294  0.342152  0.165687  0.443457

# %%
CRIME.head(1)
# Out:
#     구별  살인  강도  강간강제추행    절도    폭력  살인검거율  강도검거율  강간강제추행검거율      절도검거율  \
# 1  종로구   2   5     209  1183  1366  100.0  100.0      100.0  89.264582
#
#        폭력검거율
# 1  91.215227

# %%
CRIME_norm.head(1)
# Out:
#            살인        강도    강간강제추행        절도        폭력
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958

# %%
for crime in crime_index:
    CRIME_norm[crime+'검거율'] = CRIME[crime+'검거율']

# %%
CRIME_norm.head()
# Out:
#            살인        강도    강간강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958    NaN    NaN
# 중구   0.266667  0.294118  0.183422  0.351351  0.205574    NaN    NaN
# 용산구  0.600000  0.235294  0.342152  0.165687  0.443457    NaN    NaN
# 성동구  0.266667  0.176471  0.072310  0.097532  0.067851    NaN    NaN
# 광진구  0.066667  0.352941  0.285714  0.305523  0.180129    NaN    NaN
#
#      강간강제추행검거율  절도검거율  폭력검거율
# 구별
# 종로구        NaN    NaN    NaN
# 중구         NaN    NaN    NaN
# 용산구        NaN    NaN    NaN
# 성동구        NaN    NaN    NaN
# 광진구        NaN    NaN    NaN

# %%
CRIME.set_index('구별', inplace=True)

# %%
CRIME.head()
# Out:
#      살인  강도  강간강제추행    절도    폭력  살인검거율  강도검거율   강간강제추행검거율      절도검거율  \
# 구별
# 종로구   2   5     209  1183  1366  100.0  100.0  100.000000  89.264582
# %%
CRIME_norm.loc[:, '살인':'폭력'].sum()
# Out:
# 살인        8.266667
# 강도        5.117647
# 강간강제추행    6.522046
# 절도        9.110458
# 폭력        7.281502
# dtype: float64

# %%
CRIME_norm.loc[:, '살인':'폭력'].sum(axis=1)
# Out:
# 구별
# 종로구     1.029631
# 중구      1.301131
# 용산구     1.786590
# 성동구     0.680831
# 광진구     1.190974
# 동대문구    1.450162
# 중랑구     1.173232
# 성북구     0.486979
# 강북구     0.680111
# 도봉구     0.400000
# 노원구     1.353833
# 은평구     1.398985
# 서대문구    0.379535
# 마포구     2.011177
# 양천구     0.948938
# 강서구     1.962611
# 구로구     1.356594
# 금천구     0.778673
# 영등포구    2.464305
# 동작구     0.546650
# 관악구     2.060128
# 서초구     2.257501
# 강남구     4.762045
# 송파구     2.537177
# 강동구     1.300528
# dtype: float64

# %%
CRIME_norm['범죄'] = CRIME_norm.loc[:, '살인':'폭력'].sum(axis=1)

# %%
CRIME_norm.head(3)
# Out:
#            살인        강도    강간강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958  100.0  100.0
# 중구   0.266667  0.294118  0.183422  0.351351  0.205574   80.0  100.0
# 용산구  0.600000  0.235294  0.342152  0.165687  0.443457   60.0   75.0
#
#       강간강제추행검거율      절도검거율      폭력검거율        범죄
# 구별
# 종로구  100.000000  89.264582  91.215227  1.029631
# 중구    68.361582  58.369099  90.072993  1.301131
# 용산구   88.014981  54.436229  83.818275  1.786590

# %%
CRIME_norm['검거'] = CRIME_norm.loc[:,'살인검거율':'폭력검거율'].sum(axis=1)

# %%
CRIME_norm.head(1)
# Out:
#            살인        강도    강간강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958  100.0  100.0
#
#      강간강제추행검거율      절도검거율      폭력검거율        범죄          검거
# 구별
# 종로구      100.0  89.264582  91.215227  1.029631  480.479809

# %%
CCTV_POP = pd.read_excel('CCTV_POP.xlsx', index_col = '구 별')

# %%
CRIME_norm[['인구수', 'CCTV총계', '최근증가율', '외국인비율']] = CCTV_POP[['인구수', 'CCTV 총 계', '최근증가율', '외국인비율']] #펜시인덱싱

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\com\miniconda3\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\com\miniconda3\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\com\miniconda3\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\com\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\com\miniconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\com\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\com\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\com\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %% [markdown]
# ### seaborn - pairplot : 변수의 쌍간의 관계를 시각화

# %%
sns.pairplot(CRIME_norm[['인구수', 'CCTV총계', '최근증가율', '외국인비율', '범죄', '검거']])
plt.show()

# %%
sns.pairplot(CRIME_norm[['인구수', 'CCTV총계', '최근증가율', '외국인비율', '범죄', '검거']].reset_index(),
            hue='구별')
plt.show()

# %%
sns.pairplot(CRIME_norm[['인구수', 'CCTV총계', '최근증가율', '외국인비율', '범죄', '검거']]
            ,kind='reg')
plt.show()

# %%
CRIME_norm.head(1)
# Out:
#            살인        강도    강간강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958  100.0  100.0
#
#      강간강제추행검거율      절도검거율      폭력검거율        범죄          검거     인구수  cctv총계  \
# 구별
# 종로구      100.0  89.264582  91.215227  1.029631  480.479809  148154    3125
#
#       최근증가율    외국인비율  CCTV총계
# 구별
# 종로구  74.848  7.85399    3125

# %%
CRIME_norm['검거'].max()
# Out:
# np.float64(480.4798085122446)

# %%
CRIME_norm['검거'] = CRIME_norm['검거'] / CRIME_norm['검거'].max() * 100

# %%
CRIME_norm.head(2)
# Out:
#            살인        강도    강간강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.066667  0.294118  0.239859  0.225029  0.203958  100.0  100.0
# 중구   0.266667  0.294118  0.183422  0.351351  0.205574   80.0  100.0
#
#       강간강제추행검거율      절도검거율      폭력검거율        범죄         검거     인구수  cctv총계  \
# 구별
# 종로구  100.000000  89.264582  91.215227  1.029631  100.00000  148154    3125
# 중구    68.361582  58.369099  90.072993  1.301131   82.58488  128234    3427
#
#         최근증가율     외국인비율  CCTV총계
# 구별
# 종로구  74.84800  7.853990    3125
# 중구   36.00817  8.163981    3427

# %% [markdown]
# ### 히트맵(heatmap) : 2차원 배열의 데이터를 색상으로 시각화

# %%
plt.figure(figsize = (6, 12), dpi = 100)
sns.heatmap(CRIME_norm[['살인검거율', '강도검거율', '강간강제추행검거율', '절도검거율', '폭력검거율', '검거']], annot = True, fmt = '.2f'
           , cmap = 'YlGnBu')
plt.show()

# %%
plt.figure(figsize = (6, 12), dpi = 100)
sns.heatmap(CRIME_norm[['살인검거율', '강도검거율', '강간강제추행검거율', '절도검거율', '폭력검거율', '검거']], annot = True, fmt = '.2f'
           , cmap = 'coolwarm_r')
plt.show()

# %% [markdown]
# ## 지도에 시각화

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Collecting xyzservices
#   Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Requirement already satisfied: requests in c:\users\com\miniconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\com\miniconda3\lib\site-packages (from folium) (3.0.2)
# Requirement already satisfied: numpy in c:\users\com\miniconda3\lib\site-packages (from folium) (2.0.2)
# Collecting branca>=0.6.0
#   Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\com\miniconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\com\miniconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\com\miniconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\com\miniconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\com\miniconda3\lib\site-packages (from requests->folium) (1.26.7)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.2 folium-0.20.0 xyzservices-2026.3.0

# %%
import folium

# %%
yu_map = folium.Map(location=[35.8327, 128.7546], zoom_start=15)
yu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15d69d036290cd11a98bf788537712f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15d69d036290cd11a98bf788537712f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15d69d036290cd11a98bf788537712f9 = L.map(
#                 &quot;map_15d69d036290cd11a98bf788537712f9&quot;,
#                 {
#                     center: [35.8327, 128.7546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c91b396c869ad655fee870921b2f047a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([35.8327, 128.7546], popup='YU').add_to(yu_map)
yu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15d69d036290cd11a98bf788537712f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15d69d036290cd11a98bf788537712f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15d69d036290cd11a98bf788537712f9 = L.map(
#                 &quot;map_15d69d036290cd11a98bf788537712f9&quot;,
#                 {
#                     center: [35.8327, 128.7546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c91b396c869ad655fee870921b2f047a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#             var marker_5d751bd882760927ba4f87a2c3aec8f4 = L.marker(
#                 [35.8327, 128.7546],
#                 {
# }
#             ).addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#         var popup_71bf4e0d260d8fda235d8cd64e251779 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_267c9a1d6d4b48c0c1082632476b2056 = $(`&lt;div id=&quot;html_267c9a1d6d4b48c0c1082632476b2056&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YU&lt;/div&gt;`)[0];
#                 popup_71bf4e0d260d8fda235d8cd64e251779.setContent(html_267c9a1d6d4b48c0c1082632476b2056);
#
#
#
#         marker_5d751bd882760927ba4f87a2c3aec8f4.bindPopup(popup_71bf4e0d260d8fda235d8cd64e251779)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker([35.84, 128.7546], radius=50, popup='컴공',fill_colors='#ff0000').add_to(yu_map)
yu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15d69d036290cd11a98bf788537712f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15d69d036290cd11a98bf788537712f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15d69d036290cd11a98bf788537712f9 = L.map(
#                 &quot;map_15d69d036290cd11a98bf788537712f9&quot;,
#                 {
#                     center: [35.8327, 128.7546],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c91b396c869ad655fee870921b2f047a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#             var marker_5d751bd882760927ba4f87a2c3aec8f4 = L.marker(
#                 [35.8327, 128.7546],
#                 {
# }
#             ).addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#         var popup_71bf4e0d260d8fda235d8cd64e251779 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_267c9a1d6d4b48c0c1082632476b2056 = $(`&lt;div id=&quot;html_267c9a1d6d4b48c0c1082632476b2056&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;YU&lt;/div&gt;`)[0];
#                 popup_71bf4e0d260d8fda235d8cd64e251779.setContent(html_267c9a1d6d4b48c0c1082632476b2056);
#
#
#
#         marker_5d751bd882760927ba4f87a2c3aec8f4.bindPopup(popup_71bf4e0d260d8fda235d8cd64e251779)
#         ;
#
#
#
#
#             tile_layer_c91b396c869ad655fee870921b2f047a.addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#             var circle_marker_3f9cf2f009ac4e554db905fb32affe8a = L.circleMarker(
#                 [35.84, 128.7546],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#         var popup_c30f1a27b68ef1d2fed0fac6bfb8957d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c1fe2e9a8a8c09fccd7cb89a9e7d2d = $(`&lt;div id=&quot;html_f5c1fe2e9a8a8c09fccd7cb89a9e7d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;컴공&lt;/div&gt;`)[0];
#                 popup_c30f1a27b68ef1d2fed0fac6bfb8957d.setContent(html_f5c1fe2e9a8a8c09fccd7cb89a9e7d2d);
#
#
#
#         circle_marker_3f9cf2f009ac4e554db905fb32affe8a.bindPopup(popup_c30f1a27b68ef1d2fed0fac6bfb8957d)
#         ;
#
#
#
#
#             var circle_marker_506ee51e5b71f0572d6a88b61af1c61b = L.circleMarker(
#                 [35.84, 128.7546],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15d69d036290cd11a98bf788537712f9);
#
#
#         var popup_453157254b4c1506989d46cbf8812671 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d06b80cb7df04c1f89428f76d89bf8a = $(`&lt;div id=&quot;html_6d06b80cb7df04c1f89428f76d89bf8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;컴공&lt;/div&gt;`)[0];
#                 popup_453157254b4c1506989d46cbf8812671.setContent(html_6d06b80cb7df04c1f89428f76d89bf8a);
#
#
#
#         circle_marker_506ee51e5b71f0572d6a88b61af1c61b.bindPopup(popup_453157254b4c1506989d46cbf8812671)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#  ### 한국 지리 정보

# %%
import json

# %%
seoul_geo = json.load(open('seoul_geo.json', encoding='utf-8'))

# %%
seoul_geo
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
#       [127.1116764203608, 37.540669955324965],
#       [127.12123165719615, 37.52528270089],
#       [127.14672806823502, 37.51415680680291],
#       [127.1634944215765, 37.497445406097484],
#       [127.14206058413274, 37.47089819098501],
#       [127.12440571080893, 37.46240445587048],
#       [127.11117085201238, 37.485708381512445],
#       [127.0719146000724, 37.50224013587669],
#       [127.0690698130372, 37.522279423505026]]]}},
#   {'type': 'Feature',
#    'properties': {'code': '11230',
#     'name': '강남구',
#     'name_eng': 'Gangnam-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.05867359288398, 37.52629974922568],
#       [127.0690698130372, 37.522279423505026],
#       [127.0719146000724, 37.50224013587669],
#       [127.11117085201238, 37.485708381512445],
#       [127.12440571080893, 37.46240445587048],
#       [127.09842759318751, 37.45862253857461],
#       [127.08640440578156, 37.472697935184655],
#       [127.0559170481904, 37.4659228914077],
#       [127.03621915098798, 37.48175802427603],
#       [127.01397119667513, 37.52503988289669],
#       [127.02302831890559, 37.53231899582663],
#       [127.05867359288398, 37.52629974922568]]]}},
#   {'type': 'Feature',
#    'properties': {'code': '11220',
#     'name': '서초구',
#     'name_eng': 'Seocho-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127
gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.01070894177482, 37.54118048964762],
#       [126.98752996903328, 37.55094818807139],
#       [126.96448570553055, 37.548705692021635],
#       [126.96358226710812, 37.55605635475154],
#       [126.96873633279075, 37.56313604690827],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'properties': {'code': '11010',
#     'name': '종로구',
#     'name_eng': 'Jongno-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.977175406416, 37.62859715400388],
#       [126.98879865992384, 37.6118927319756],
#       [126.99348293358314, 37.588565457216156],
#       [127.02527254528003, 37.57524616245249],
#       [127.02547266349976, 37.568943552237734],
#       [126.96873633279075, 37.56313604690827],
#       [126.95565425846463, 37.576080790881456],
#       [126.9524752030572, 37.60508692737045],
#       [126.95427017006129, 37.622033431339425],
#       [126.9738864128702, 37.62949634786888]]]}}]}

# %%
seoul_map = folium.Map(location=[37.5502, 126.982], zoom_start=12)

# 코로폴리스맵 : 지리적 구역을 나눠놓은 지도
folium.Choropleth(
    geo_data=seoul_geo,
    data=CRIME_norm['범죄'],
    columns=[CRIME_norm.index, CRIME_norm['범죄']],
    fill_color='PuRd',
    key_on='feature.properties.name'
).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01f908fa56b6d92ea7e241fc16a1dc69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01f908fa56b6d92ea7e241fc16a1dc69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01f908fa56b6d92ea7e241fc16a1dc69 = L.map(
#                 &quot;map_01f908fa56b6d92ea7e241fc16a1dc69&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66d07d2e929c6a2db6210f51801b2115 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66d07d2e929c6a2db6210f51801b2115.addTo(map_01f908fa56b6d92ea7e241fc16a1dc69);
#
#
#             var choropleth_ffc814d57b434b58437aa7e23b2e1478 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_40a1247f9ede9f3763c2bd1896f065e3_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11240&quot;: case &quot;11220&quot;: case &quot;11210&quot;: case &quot;11190&quot;: case &quot;11160&quot;: case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11180&quot;: case &quot;11150&quot;: case &quot;11130&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11080&quot;: case &quot;11040&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_40a1247f9ede9f3763c2bd1896f065e3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_40a1247f9ede9f3763c2bd1896f065e3 = L.geoJson(null, {
#                 onEachFeature: geo_json_40a1247f9ede9f3763c2bd1896f065e3_onEachFeature,
#
#                 style: geo_json_40a1247f9ede9f3763c2bd1896f065e3_styler,
#             ...{
# }
#         });
#
#         function geo_json_40a1247f9ede9f3763c2bd1896f065e3_add (data) {
#             geo_json_40a1247f9ede9f3763c2bd1896f065e3
#                 .addData(data);
#         }
#             geo_json_40a1247f9ede9f3763c2bd1896f065e3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;: &quot;Songpa-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.05867359288398, 37.52629974922568], [127.0690698130372, 37.522279423505026], [127.0719146000724, 37.50224013587669],
